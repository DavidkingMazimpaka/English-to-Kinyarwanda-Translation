# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidkingMazimpaka/English-to-Kinyarwanda-Translation/blob/main/English_to_Kinyarwanda_Translation_with_RNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **English_to_Kinyarwanda_Translation_with_RNNs**

# %% [markdown]
# To build a model that translates text from English to Kinyarwanda, we can use the Kinyarwanda-English parallel dataset provided by Digital Umuganda on Hugging Face. This dataset contains 48,000 Kinyarwanda-English parallel sentences, which is suitable for training a machine translation model.

# %% [markdown]
# **STEPS TO BUILD THE TRANSLATION MODEL**

# %% [markdown]
# **1. Data Collection and Preprocessing**

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Embedding, GRU, Dense, Bidirectional
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction



# Function to read data with specific encoding and error handling
def read_data_with_encoding(url, encoding='utf-8'):
    try:
        return pd.read_csv(url, sep='\t', names=['English', 'Kinyarwanda'], encoding=encoding, on_bad_lines='skip')
    except UnicodeDecodeError:
        print(f"UnicodeDecodeError encountered while reading {url} with encoding {encoding}")
        return None

# Load the datasets
urls = [
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus2.tsv',
    'https://huggingface.co/datasets/DigitalUmuganda/kinyarwanda-english-machine-translation-dataset/resolve/main/kinyarwanda-english-corpus3.tsv'
]

dfs = [read_data_with_encoding(url, encoding='ISO-8859-1') for url in urls]
df = pd.concat(dfs, ignore_index=True)

# Drop any rows with NaN values
df.dropna(inplace=True)

# Preprocess the text
def preprocess(text):
    text = text.lower()
    text = ''.join(char for char in text if char.isalnum() or char.isspace())
    return text

df['English'] = df['English'].apply(preprocess)
df['Kinyarwanda'] = df['Kinyarwanda'].apply(preprocess)

# Add special tokens
def add_special_tokens(texts):
    return ['<start> ' + text + ' <end>' for text in texts]

df['English'] = add_special_tokens(df['English'])
df['Kinyarwanda'] = add_special_tokens(df['Kinyarwanda'])

# Split the data into training and validation sets
train_data, val_data = train_test_split(df, test_size=0.2, random_state=42)

# %% [markdown]
# **2. TOKENIZATION AND PADDING**
#
# >Converts text into sequences of integers, and ensures these sequences are of equal length by performing tokenization and padding.

# %%
# Tokenize the text
def tokenize_text(texts):
    tokenizer = Tokenizer(filters='')
    tokenizer.fit_on_texts(texts)
    sequences = tokenizer.texts_to_sequences(texts)
    return sequences, tokenizer

# Tokenize English and Kinyarwanda texts
english_texts = train_data['English'].tolist()
kinyarwanda_texts = train_data['Kinyarwanda'].tolist()

english_sequences, english_tokenizer = tokenize_text(english_texts)
kinyarwanda_sequences, kinyarwanda_tokenizer = tokenize_text(kinyarwanda_texts)

# Pad sequences
max_seq_length = max(max(len(seq) for seq in english_sequences), max(len(seq) for seq in kinyarwanda_sequences))
english_padded = pad_sequences(english_sequences, maxlen=max_seq_length, padding='post')
kinyarwanda_padded = pad_sequences(kinyarwanda_sequences, maxlen=max_seq_length, padding='post')

# Convert to numpy arrays
english_padded = np.array(english_padded)
kinyarwanda_padded = np.array(kinyarwanda_padded)

# Ensure inp_lang and targ_lang are defined correctly
inp_lang = english_tokenizer
targ_lang = kinyarwanda_tokenizer
max_length_inp = max_seq_length
max_length_targ = max_seq_length

# %% [markdown]
# **3. Model Development**

# %% [markdown]
# For the translation model, we'll use an RNN-based architecture with an encoder-decoder structure. We can use GRU or LSTM units for the RNNs, and integrate pre-trained word embeddings like Word2Vec or GloVe.

# %% [markdown]
# **Example code for building the model:**

# %%
# Define the Encoder
class Encoder(Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = Bidirectional(GRU(self.enc_units,
                                     return_sequences=True,
                                     return_state=True,
                                     recurrent_initializer='glorot_uniform'))

    def call(self, x, hidden):
        x = self.embedding(x)
        output, forward_h, backward_h = self.gru(x, initial_state=hidden)
        state = tf.concat([forward_h, backward_h], axis=-1)
        return output, state

    def initialize_hidden_state(self, batch_size):
        return [tf.zeros((batch_size, self.enc_units)) for _ in range(2)]

# Define the Decoder
class Decoder(Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = Embedding(vocab_size, embedding_dim)
        self.gru = GRU(self.dec_units,
                       return_sequences=True,
                       return_state=True,
                       recurrent_initializer='glorot_uniform')
        self.fc = Dense(vocab_size)

    def call(self, x, hidden, enc_output):
        x = self.embedding(x)
        output, state = self.gru(x, initial_state=hidden)
        output = self.fc(output)
        return output, state

# Initialize model parameters
embedding_dim = 256
units = 512
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1
BATCH_SIZE = 64

# Instantiate Encoder and Decoder
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)
decoder = Decoder(vocab_tar_size, embedding_dim, units * 2, BATCH_SIZE)

# %% [markdown]
# **4. Training the Model**

# %% [markdown]
# Train the model with the prepared dataset, tuning the hyperparameters like batch size, learning rate, and the number of epochs.

# %% [markdown]
# **Example code for training:**

# %%
# Training process
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

# Training step function
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0
    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)
        dec_hidden = enc_hidden
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)
        for t in range(1, targ.shape[1]):
            predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_output)
            loss += loss_function(targ[:, t], predictions)
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))
    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %% [markdown]
# **5. Evaluation**

# %% [markdown]
# Evaluate the model using metrics such as BLEU score and human evaluations to ensure the translations are accurate and fluent.

# %% [markdown]
# **Example code for evaluation:**

# %% [markdown]
# **Calculate BLEU score for a batch of sentences**

# %%
# Evaluation function
def evaluate(sentence):
    sentence = '<start> ' + sentence + ' <end>'
    inputs = [inp_lang.word_index.get(i, 0) for i in sentence.split(' ')]
    inputs = pad_sequences([inputs], maxlen=max_length_inp, padding='post')
    inputs = tf.convert_to_tensor(inputs)

    result = ''
    hidden = encoder.initialize_hidden_state(1)
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden = decoder(dec_input, dec_hidden, enc_out)
        predicted_id = tf.argmax(predictions[0, -1]).numpy().item()  # Convert to integer

        # Debugging output
        print(f"Step {t}: Predicted ID: {predicted_id}, Result so far: '{result}'")

        # Check if predicted_id exists in target language vocabulary
        if predicted_id not in targ_lang.index_word:
            print(f"Warning: predicted_id {predicted_id} not found in index_word.")
            break  # Exit loop if not found

        # Check for padding
        if predicted_id == 0:
            print("Predicted padding token, breaking loop.")
            break

        result += targ_lang.index_word[predicted_id] + ' '

        # Check for end token
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence

        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence

# Calculate BLEU score for a batch of sentences
def calculate_bleu(reference, candidate):
    smoothing_function = SmoothingFunction().method4
    return sentence_bleu([reference.split()], candidate.split(), smoothing_function=smoothing_function)

def evaluate_batch(test_data):
    total_bleu_score = 0.0
    for idx, row in test_data.iterrows():
        reference = row['Kinyarwanda']
        candidate, _ = evaluate(row['English'])
        bleu_score = calculate_bleu(reference, candidate)
        total_bleu_score += bleu_score
        print(f"Reference: {reference}")
        print(f"Candidate: {candidate}")
        print(f"BLEU score: {bleu_score}")
    average_bleu_score = total_bleu_score / len(test_data)
    print(f"Average BLEU score: {average_bleu_score}")
    return average_bleu_score

# Example evaluation call
example_sentence = "hello how are you"
translation, sentence = evaluate(example_sentence)
print(f'Translation: {translation}')

# Evaluate BLEU score on validation data
average_bleu_score = evaluate_batch(val_data)
print(f'Average BLEU score on validation data: {average_bleu_score}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Step 11: Predicted ID: 7366, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas '
# Step 12: Predicted ID: 10723, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea '
# Step 13: Predicted ID: 7280, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization '
# Step 14: Predicted ID: 6979, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist '
# Step 15: Predicted ID: 2939, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan '
# Step 16: Predicted ID: 6459, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits '
# Step 17: Predicted ID: 10117, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits bang '
# Step 18: Predicted ID: 9550, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits bang revealing '
# Step 19: Predicted ID: 1897, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits bang revealing rumende '
# Step 20: Predicted ID: 2236, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits bang revealing rumende teenage '
# Step 21: Predicted ID: 6830, Result so far: 'befallen ids ingrained carpet sauls begs stripped tableware idly scrolls priyankas arimathea characterization motorist orphan hits bang revealing rumende teenage fin
Result so far: 'befallen befallen tract testifying kigeli spain deceit disobeyed deceit disobeyed bag third carrying months employs entertaining habits snokel boston porridge makuza dissemination sitric sleepless excelled nourished professional clouds poor scotia throne throne moaning rwigema failed told favor euphrates vans '
# Step 40: Predicted ID: 11798, Result so far: 'befallen befallen tract testifying kigeli spain deceit disobeyed deceit disobeyed bag third carrying months employs entertaining habits snokel boston porridge makuza dissemination sitric sleepless excelled nourished professional clouds poor scotia throne throne moaning rwigema failed told favor euphrates vans finally '
# Reference: <start> but im learning it  <end>
# Candidate: befallen befallen tract testifying kigeli spain deceit disobeyed deceit disobeyed bag third carrying months employs entertaining habits snokel boston porridge makuza dissemination sitric sleepless excelled nourished professional clouds poor scotia throne throne moaning rwigema failed told favor euphrates vans finally stewards
# BLEU score: 0
# Step 0: Predicted ID: 6182, Result so far: ''
# Step 1: Predicted ID: 2304, Result so far: 'fortunate '
# Step 2: Predicted ID: 5807, Result so far: 'fortunate note '
# Step 3: Predicted ID: 8149, Result so far: 'fortunate note kaguta '
# Step 4: Predicted ID: 6845, Result so far: 'fortunate note kaguta rwarukara '
# Step 5: Predicted ID: 9036, Result so far: 'fortunate note kaguta rwarukara lobby '
# Step 6: Predicted ID: 355, Result so far: 'fortunate note kaguta rwarukara lobby chinatown '
# Step 7: Predicted ID: 5234, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few '
# Step 8: Predicted ID: 7061, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds '
# Step 9: Predicted ID: 3221, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush '
# Step 10: Predicted ID: 8612, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary '
# Step 11: Predicted ID: 9275, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor '
# Step 12: Predicted ID: 10338, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory '
# Step 13: Predicted ID: 9159, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally '
# Step 14: Predicted ID: 1715, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage '
# Step 15: Predicted ID: 1871, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve '
# Step 16: Predicted ID: 9494, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck '
# Step 17: Predicted ID: 7631, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly '
# Step 18: Predicted ID: 2491, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew '
# Step 19: Predicted ID: 10513, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear '
# Step 20: Predicted ID: 7627, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife '
# Step 21: Predicted ID: 10686, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing '
# Step 22: Predicted ID: 6898, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale '
# Step 23: Predicted ID: 7622, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery '
# Step 24: Predicted ID: 7005, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold '
# Step 25: Predicted ID: 4051, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy '
# Step 26: Predicted ID: 8098, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury '
# Step 27: Predicted ID: 6611, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna '
# Step 28: Predicted ID: 2874, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian '
# Step 29: Predicted ID: 3045, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender '
# Step 30: Predicted ID: 8281, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended '
# Step 31: Predicted ID: 8465, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps '
# Step 32: Predicted ID: 8795, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz '
# Step 33: Predicted ID: 1358, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango '
# Step 34: Predicted ID: 1358, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends '
# Step 35: Predicted ID: 2725, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends '
# Step 36: Predicted ID: 4275, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs '
# Step 37: Predicted ID: 5115, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs awake '
# Step 38: Predicted ID: 11233, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs awake gatutsi '
# Step 39: Predicted ID: 2994, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs awake gatutsi umuti '
# Step 40: Predicted ID: 7606, Result so far: 'fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs awake gatutsi umuti aid '
# Reference: <start> they were already in the blood of christ <end>
# Candidate: fortunate note kaguta rwarukara lobby chinatown few blinds kush missionary ancestor doormotory morally frenchlanguage improve neck secretly blew gear exwife specializing ale archery haveold gypsy bury rihanna hawaiian gender suspended camps benz ntango depends depends mrs awake gatutsi umuti aid denko
# BLEU score: 0
# Step 0: Predicted ID: 3022, Result so far: ''
# Step 1: Predicted ID: 760, Result so far: 'sickle '
# Step 2: Predicted ID: 9915, Result so far: 'sickle spoke '
# Step 3: Predicted ID: 10276, Result so far: 'sickle spoke celcius '
# Step 4: Predicted ID: 9249, Result so far: 'sickle spoke celcius calvary '
# Step 5: Predicted ID: 5320, Result so far: 'sickle spoke celcius calvary hapiness '
# Step 6: Predicted ID: 5320, Result so far: 'sickle spoke celcius calvary hapiness lounge '
# Step 7: Predicted ID: 2802, Result so far: 'sickle spoke celcius calvary hapiness lounge lounge '
# Step 8: Predicted ID: 10766, Result so far: 'sickle spoke celcius calvary hapiness lounge lounge poorly '
# Step 9: Predicted ID: 1660, Result so far: 'sickle spoke celcius calvary hapiness lounge lounge poorly flat '
# Step 10: Predicted ID: 9107, Result so far: 'sickle spoke celcius calvary hapiness lounge lounge poorly flat